# %%
from Read_data import read_data

def main():
    data = read_data()
    print(data)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from data.Read_data import read_data
#       3 def main():
#       4     data = read_data()
#
# ModuleNotFoundError: No module named 'data'
